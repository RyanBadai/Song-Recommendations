# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from scipy import stats
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.model_selection import GridSearchCV, train_test_split

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("breast-cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Clean Dataset

# %% [markdown]
# ### Check Null Value

# %%
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# ### Outliers in Dataset

# %%
numeric_column = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 
                  'compactness_mean']

plt.figure(figsize = (12, 6))
sns.boxplot(data = df[numeric_column])
plt.title('Box Plot for Numeric Column')
plt.show()

# %%
numeric_column = ['concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 
                  'radius_se', 'texture_se']

plt.figure(figsize = (12, 6))
sns.boxplot(data = df[numeric_column])
plt.title('Box Plot for Numeric Column')
plt.show()

# %%
numeric_column = ['perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 
                  'concave points_se']

plt.figure(figsize = (12, 6))
sns.boxplot(data = df[numeric_column])
plt.title('Box Plot for Numeric Column')
plt.show()

# %%
numeric_column = [ 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst',
                  'perimeter_worst', 'area_worst']

plt.figure(figsize = (12, 6))
sns.boxplot(data = df[numeric_column])
plt.title('Box Plot for Numeric Column')
plt.show()

# %%
numeric_column = ['smoothness_worst', 'compactness_worst', 'concavity_worst',  'concave points_worst', 
                  'symmetry_worst', 'fractal_dimension_worst']

plt.figure(figsize = (12, 6))
sns.boxplot(data = df[numeric_column])
plt.title('Box Plot for Numeric Column')
plt.show()

# %%
outlier_column = ['area_mean', 'radius_se', 'texture_se', 'area_se', 'area_worst', 'compactness_worst',
                 'concavity_worst', 'symmetry_worst']

for column in outlier_column:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    df = df[~((df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR)))]

df.shape
# Out:
# (391, 32)

# %% [markdown]
# # Correlation Matrix in Dataset

# %%
plt.figure(figsize=(25, 21))
correlation_matrix = df.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, )
plt.title("Correlation Matrix ", size=50)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix ')

# %% [markdown]
# # Fix Value in Dataset

# %%
df["diagnosis"] = df["diagnosis"].replace({'M': 0, 'B': 1})
df.head()
# Out:
#           id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 7   84458202          0        13.71         20.83           90.20      577.9
# 10    845636          0        16.02         23.24          102.70      797.8
# 13    846381          0        15.85         23.95          103.70      782.7
# 16    848406          0        14.68         20.13           94.74      684.5
# 19   8510426          1        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 7           0.11890           0.16450         0.09366              0.05985
# 10          0.08206           0.06669         0.03299              0.03323
# 13          0.08401           0.10020         0.09938              0.05364
# 16          0.09867           0.07200         0.07395              0.05259
# 19          0.09779           0.08129         0.06664              0.04781
#
# ...

# %% [markdown]
# # Delete ID Column

# %%
df = df.drop(columns=['id'])
df.head()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 7           0        13.71         20.83           90.20      577.9
# 10          0        16.02         23.24          102.70      797.8
# 13          0        15.85         23.95          103.70      782.7
# 16          0        14.68         20.13           94.74      684.5
# 19          1        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 7           0.11890           0.16450         0.09366              0.05985
# 10          0.08206           0.06669         0.03299              0.03323
# 13          0.08401           0.10020         0.09938              0.05364
# 16          0.09867           0.07200         0.07395              0.05259
# 19          0.09779           0.08129         0.06664              0.04781
#
#     symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# # Split The Dataset

# %%
x = df.drop(columns = 'diagnosis')
y = df.diagnosis

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
print("Unique classes in y_train:", np.unique(y_train))
# Out:
# Unique classes in y_train: [0 1]

# %% [markdown]
# # Hyperparameter Tunning

# %%
parameters = {'C': [0.1, 1, 10],
              'kernel': ['linear', 'rbf'],
              'gamma': [1, 0.1, 0.001]}

# %%
svm_model = svm.SVC()

grid_search = GridSearchCV(SVC(), parameters, verbose=3)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.927 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.927 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.927 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.907 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.963 total time=   0.0s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.836 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.836 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.927 total time=   0.0s
# ...

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'linear'}

# %% [markdown]
# # Performance of The Model

# %% [markdown]
# ### Accuracy

# %%
y_pred = grid_search.predict(X_test)
accuracy_svm = accuracy_score(y_test, y_pred)
print(accuracy_svm)
# Out:
# 0.9661016949152542

# %% [markdown]
# ### Confusion Matrix

# %%
svm_classification_report = classification_report(y_test, y_pred)
print(svm_classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        11
#            1       0.98      0.98      0.98       107
#
#     accuracy                           0.97       118
#    macro avg       0.90      0.90      0.90       118
# weighted avg       0.97      0.97      0.97       118
